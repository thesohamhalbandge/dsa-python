# %% [markdown]
#     Data Types:
#         - Primitive Data Types:
#             - int
#             - float
#             - bool
#             - string
#             - None
#         - Collections
#             - List
#             - Tuple
#             - Dictionary
#             - Set
#             - String

# %% [markdown]
# # List
#
#     - access the element from the index
#     - add something to the list
#     - remove from the list
#     - slice a list
#     - join two lists

# %%
## creating a list
students_list = ["Rajiv", "Manya", "Siddhi", "Anubhav"]

# %%
type(students_list)
# Out:
# list

# %%
print(students_list)
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav']

# %%
## acess the elements of the list
print(students_list[1])
print(students_list[2])
# Out:
# Manya
# Siddhi

# %%
## what is the length of the list
len(students_list) ## index will range from 0 - 3
# Out:
# 4

# %%
## what is the last element in the list
students_list[len(students_list) - 1]

students_list[-1]  ## accessing the last element
# Out:
# 'Anubhav'

# %%
## what is the 2nd last element in the list

marks  = [30, 100, 40, 50, 20, 70, 25]

# marks[len(marks) - 2 ]
marks[- 2]
# Out:
# 70

# %%
## Add a new student in the list

students_list = ["Rajiv", "Manya", "Siddhi", "Anubhav"]

new_student = "Shabana"

students_list.append(new_student) ## this will add new_student to the list

students_list
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana']

# %%
len(students_list)
# Out:
# 5

# %%
## remove a student from the list
print(students_list)
students_list.remove("Anubhav")
print(students_list)
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana']
# ['Rajiv', 'Manya', 'Siddhi', 'Shabana']

# %%
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana']
students_list.append("Anubhav")
students_list
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Anubhav']

# %%
print(students_list)
students_list.remove("Anubhav")
print(students_list)
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Anubhav']
# ['Rajiv', 'Manya', 'Siddhi', 'Shabana', 'Anubhav']

# %%
# Slice the list ( take some portion of the list)


# Question: Give me the first 3 students in the list
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana']

first_three_students = [students_list[0], students_list[1], students_list[2]]
print(first_three_students)

students_list[0 : 3] ## means take first three students at index 0, 1, 2
# Out:
# ['Rajiv', 'Manya', 'Siddhi']
# ['Rajiv', 'Manya', 'Siddhi']

# %%
# Question: Give me the 2 - 5 students in the list
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]

students_list[2 : 6]
# Out:
# ['Siddhi', 'Anubhav', 'Shabana', 'Debashish']

# %%
print(dir(students_list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %% [markdown]
# ## Common operations on list
#     'append',
#     'clear',
#     'copy',
#     'count',
#     'extend',
#     'index',
#     'insert',
#     'pop',
#     'remove',
#     'reverse',
#     'sort'

# %%
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]

students_list.clear()

# %%
students_list
# Out:
# []

# %%
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]
backup_list = students_list.copy()

# %%
backup_list
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Debashish']

# %%
id(students_list), id(backup_list)
# Out:
# (4423558848, 4424383808)

# %%
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]
students_list.append("Anubhav")
students_list.count("Anubhav")
# Out:
# 2

# %%
students_list.append("Rajiv")  # in-place operation ( As opposed to non-inplace method that return a view)

# %%
print(students_list)
students_list.count("Rajiv")
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Debashish', 'Anubhav', 'Rajiv', 'Rajiv', 'Rajiv']
# 4

# %%
# list.extend(iterable)
# Extend the list by appending all the items from the iterable. Similar to a[len(a):] = iterable.


students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]

new_admission = ["Ram", "Harsh"]


# students_list.append(new_admission[0])
# students_list.append(new_admission[1])

students_list.extend(new_admission)

print(students_list)

students_list[len(students_list):] = new_admission
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Debashish', 'Ram', 'Harsh']

# %%
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]
students_list[len(students_list):] = new_admission
print(students_list)
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Debashish', 'Ram', 'Harsh']

# %%
students_list[len(students_list):] = ["Rohan", "Mohan"]
students_list
# Out:
# ['Rajiv',
#  'Manya',
#  'Siddhi',
#  'Anubhav',
#  'Shabana',
#  'Debashish',
#  'Ram',
#  'Harsh',
#  'Rohan',
#  'Mohan']

# %%
students_list = ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', "Debashish"]
students_list.append("Anubhav")
print(students_list)
students_list.count("Anubhav")
# Out:
# ['Rajiv', 'Manya', 'Siddhi', 'Anubhav', 'Shabana', 'Debashish', 'Anubhav']
# 2

# %%
students_list.insert(2, "Ram")

# %%
students_list
# Out:
# ['Rajiv',
#  'Manya',
#  'Ram',
#  'Siddhi',
#  'Anubhav',
#  'Shabana',
#  'Debashish',
#  'Anubhav']

# %%
students_list.insert(len(students_list), "Harsh")
students_list.append("Harsh")

# %%
students_list
# Out:
# ['Rajiv',
#  'Manya',
#  'Ram',
#  'Siddhi',
#  'Anubhav',
#  'Shabana',
#  'Debashish',
#  'Anubhav',
#  'Harsh']

# %%
## pop

students_list = ['Rajiv',
 'Manya',
 'Ram',
 'Siddhi',
 'Anubhav',
 'Shabana',
 'Debashish',
 'Anubhav',
 'Harsh']


removed_student = students_list.pop()
print(removed_student)
# Out:
# Harsh

# %%
removed_student = students_list.pop()
print(removed_student)
print(students_list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 removed_student = students_list.pop()
#       2 print(removed_student)
#       3 print(students_list)
#
# IndexError: pop from empty list

# %%
students_list = ['Rajiv',
 'Manya',
 'Ram',
 'Siddhi',
 'Anubhav',
 'Shabana',
 'Debashish',
 'Anubhav',
 'Harsh']


students_list.pop(1)
print(students_list)
# Out:
# ['Rajiv', 'Ram', 'Siddhi', 'Anubhav', 'Shabana', 'Debashish', 'Anubhav', 'Harsh']

# %%
students_list = ['Rajiv',
 'Manya',
 'Ram',
 'Siddhi',
 'Anubhav',
 'Shabana',
 'Debashish',
 'Anubhav',
 'Harsh']


students_list[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[97], line 12
#       1 students_list = ['Rajiv',
#       2  'Manya',
#       3  'Ram',
#    (...)      8  'Anubhav',
#       9  'Harsh']
# ---> 12 students_list[9]
#
# IndexError: list index out of range

# %%
## sort

marks = [40, 30.5, 20, -45, 70, 10]

marks.sort()  # in place operation

print(marks)
# Out:
# [-45, 10, 20, 30.5, 40, 70]

# %%
marks = [40, 30.5, 20, -45, 70, 10]

marks.sort(reverse = True)  # in place operation

print(marks)
# Out:
# [70, 40, 30.5, 20, 10, -45]

# %%
print(marks)
marks.index(10)
# Out:
# [70, 40, 30.5, 20, 10, -45]
# 4

# %% [markdown]
# ## Nested list

# %%
internal_marks = [20, 15, 12, 10]
external_marks = [90, 70, 55, 60]

all_marks = [internal_marks, external_marks]
all_marks
# Out:
# [[20, 15, 12, 10], [90, 70, 55, 60]]

# %%
# a list can contain all datatype
my_list = [ [ 10, 12, [17, 18, 19]], ["Siddhi", "Manya"], "apple", "mango", 100, 200.5 ]

my_list[0][-1]
# Out:
# [17, 18, 19]

# %%
my_matrix = [
    [1, 2, 3], 
    [4, 5, 6], 
    [10, 11, 12]
]

# %%
my_matrix[0], my_matrix[1]
# Out:
# ([1, 2, 3], [4, 5, 6])

# %% [markdown]
# # Dictionary
#
#     Common operations on a dictionary:
#         - Add a key
#         - remove a key
#         - Change the value of a key

# %%
## create a dictionary
country_dict = {
        "India" : "New Delhi", 
        "USA" : "Washington DC", 
        "England" :"London"
}

country_dict
# Out:
# {'India': 'New Delhi', 'USA': 'Washington DC', 'England': 'London'}

# %%
len(country_dict)
# Out:
# 3

# %%
type(country_dict)
# Out:
# dict

# %%
print(dir(country_dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %% [markdown]
# ## Methods on a dictionary
#
#     'clear',
#     'copy',
#     'fromkeys',
#     'get',
#     'items',
#     'keys',
#     'pop',
#     'popitem',
#     'setdefault',
#     'update',
#     'values'

# %%
country_dict = {
        "India" : "New Delhi", 
        "USA" : "Washington DC", 
        "England" :"London"
}

country_dict.clear()
country_dict
# Out:
# {}

# %%
## acess the value in the dictionary using a key

country_dict = {
        "India" : "New Delhi", 
        "USA" : "Washington DC", 
        "England" :"London"
}
print(country_dict["India"]) 
print(country_dict["France"])
# Out:
# New Delhi
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 9
#       3 country_dict = {
#       4         "India" : "New Delhi",
#       5         "USA" : "Washington DC",
#       6         "England" :"London"
#       7 }
#       8 print(country_dict["India"])
# ----> 9 print(country_dict["France"])
#
# KeyError: 'France'

# %%
country_dict = {
        "India" : "New Delhi", 
        "USA" : "Washington DC", 
        "England" :"London"
}

## if we use get then we can access the value if the key is present. Otherwise, it will return default value
print(country_dict.get("India"))
print(country_dict.get("France", "n/a"))
print(country_dict.get("France", {}))
# Out:
# New Delhi
# n/a
# {}

# %%
marks = {

    "Siddhi" : 40, 
    "Shabana" : 45, 
    "Debashish" : 70
    
}

print("Keys = ", list(marks.keys()))
print("Values = " , list(marks.values()))

print(marks["Siddhi"])
print(marks["Rajiv"]) ## key error
# Out:
# Keys =  ['Siddhi', 'Shabana', 'Debashish']
# Values =  [40, 45, 70]
# 40
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 13
#      10 print("Values = " , list(marks.values()))
#      12 print(marks["Siddhi"])
# ---> 13 print(marks["Rajiv"])
#
# KeyError: 'Rajiv'

# %%
marks = {

    "Siddhi" : [40, 30, 80], 
    "Shabana" : [45, 70], 
    "Debashish" : [30, 60, 40, 10, 70]
    
}


marks["Debashish"]
# Out:
# [30, 60, 40, 10, 70]

# %%
# nested dictionary

marks = {

    "Siddhi" : {"English": 40, 
                "Hindi":30, 
                "Math": {"theory" : 80 , "practical":50}}, 
    
    "Shabana" : {"Science":45, "English" : 70}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":90}, 
                   "Science" : 10, 
                    "Art": 70}
    
}

student = "Shabana"
subject = "Science"
# marks[student]["Hindi"]


# marks[student][subject]["theory"]
marks.get(student, {}).get(subject, {}).get("theory", None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[156], line 25
#      20 subject = "Science"
#      21 # marks[student]["Hindi"]
#      22
#      23
#      24 # marks[student][subject]["theory"]
# ---> 25 marks.get(student, {}).get(subject, {}).get("theory", None)
#
# AttributeError: 'int' object has no attribute 'get'

# %% [markdown]
#     'pop',
#     'popitem',
#     'setdefault',
#     'update',

# %%
marks = {

    "Siddhi" : {"English": 40, 
                "Hindi":30, 
                "Math": {"theory" : 80 , "practical":50}}, 
    
    "Shabana" : {"Science":45, "English" : 70}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":90}, 
                   "Science" : 10, 
                    "Art": 70}
    
}


print(marks)

popped = marks.pop( "Debashish" )

print("popped =" , popped )


print(marks)
# Out:
# {'Siddhi': {'English': 40, 'Hindi': 30, 'Math': {'theory': 80, 'practical': 50}}, 'Shabana': {'Science': 45, 'English': 70}, 'Debashish': {'English': 30, 'Hindi': 60, 'Math': {'theory': 40, 'practical': 90}, 'Science': 10, 'Art': 70}}
# popped = {'English': 30, 'Hindi': 60, 'Math': {'theory': 40, 'practical': 90}, 'Science': 10, 'Art': 70}
# {'Siddhi': {'English': 40, 'Hindi': 30, 'Math': {'theory': 80, 'practical': 50}}, 'Shabana': {'Science': 45, 'English': 70}}

# %%
marks = {

    "Siddhi" : {"English": 40, 
                "Hindi":30, 
                "Math": {"theory" : 80 , "practical":50}}, 
    
    "Shabana" : {"Science":45, "English" : 70}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":90}, 
                   "Science" : 10, 
                    "Art": 70}
    
}


marks.popitem()
# Out:
# ('Debashish',
#  {'English': 30,
#   'Hindi': 60,
#   'Math': {'theory': 40, 'practical': 90},
#   'Science': 10,
#   'Art': 70})

# %%
marks = {

    "Siddhi" : {"English": 40, 
                "Hindi":30, 
                "Math": {"theory" : 80 , "practical":50}}, 
    
    "Shabana" : {"Science":45, "English" : 70}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":90}, 
                   "Science" : 10, 
                    "Art": 70}
    
}


update_marks = {

    "Siddhi" : {"English": 45}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":92}, 
                   "Science" : 10, 
                    "Art": 70}
    
}


marks.update(update_marks)

print(marks)
# Out:
# {'Siddhi': {'English': 45}, 'Shabana': {'Science': 45, 'English': 70}, 'Debashish': {'English': 30, 'Hindi': 60, 'Math': {'theory': 40, 'practical': 92}, 'Science': 10, 'Art': 70}}

# %%
marks = {

    "Siddhi" : {"English": 40, 
                "Hindi":30, 
                "Math": {"theory" : 80 , "practical":50}}, 
    
    "Shabana" : {"Science":45, "English" : 70}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":90}, 
                   "Science" : 10, 
                    "Art": 70}
}


new_value = marks["Shabana"]
new_value


del marks["Shabana"]

# %%
marks["Shahana"] =new_value

# %%
marks
# Out:
# {'Siddhi': {'English': 40,
#   'Hindi': 30,
#   'Math': {'theory': 80, 'practical': 50}},
#  'Debashish': {'English': 30,
#   'Hindi': 60,
#   'Math': {'theory': 40, 'practical': 90},
#   'Science': 10,
#   'Art': 70},
#  'Shahana': {'Science': 45, 'English': 70}}

# %%
marks.setdefault("Siddhi", {})
marks.setdefault("Rajiv", {})


# marks.setdefault()
# Out:
# {}

# %%
marks
# Out:
# {'Siddhi': {'English': 40,
#   'Hindi': 30,
#   'Math': {'theory': 80, 'practical': 50}},
#  'Debashish': {'English': 30,
#   'Hindi': 60,
#   'Math': {'theory': 40, 'practical': 90},
#   'Science': 10,
#   'Art': 70},
#  'Shahana': {'Science': 45, 'English': 70},
#  'Rajiv': {}}

# %% [markdown]
# python```empty_list = []
# empty_dict = {}
# empty_tuple = ()
# ```

# %% [markdown]
# # Tuple
#
#     - ordered and immutable collection of items in python
#     -

# %%
## Create a tuple
empty_tuple = ()
print(type(empty_tuple))
my_tuple = (20, 30)
# Out:
# <class 'tuple'>

# %%
another_tuple = ("harsh", ) ## tuple with length 1
another_tuple, type(another_tuple)
# Out:
# ('harsh', str)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 2

# %%
## acess the values in the tuple
my_tuple[0], my_tuple[1]
# Out:
# (20, 30)

# %%
## tuples are immutable
my_tuple.append(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 ## tuples are immutable
# ----> 2 my_tuple.append(40)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
## what are the methods or attributes available for a tuple

print(dir(my_tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
students_tuple = ("harsh", "manya", "rajiv", "harsh")
students_tuple.count("manya")
# Out:
# 1

# %%
students_tuple.index("rajiv"), students_tuple.index("harsh")
# Out:
# (2, 0)

# %%
### more operations on tuple

tuple1 = ("harsh", "anubhav")
tuple2 = ("manya", "siddhi" )


tuple3 = tuple1 + tuple2

print(tuple3)
# Out:
# ('harsh', 'anubhav', 'manya', 'siddhi')

# %%
## slicing in a tuple


# get last two elements in the tuple

tuple3[-2 : len(tuple3)]
# Out:
# ('manya', 'siddhi')

# %%
## convert a tuple to a list  ( list to tuple is also possible)

my_students = list(tuple3)
my_students
# Out:
# ['harsh', 'anubhav', 'manya', 'siddhi']

# %%
another_tuple = tuple(my_students)
another_tuple
# Out:
# ('harsh', 'anubhav', 'manya', 'siddhi')

# %%
## tuple having multiple datatypes
mixed_tuple = (2, 3.5, [ "harsh",  "debashish" ], ("rajiv", "shabana"))
mixed_tuple
# Out:
# (2, 3.5, ['harsh', 'debashish'], ('rajiv', 'shabana'))

# %%
mixed_tuple[2].append("manya")

# %%
mixed_tuple
# Out:
# (2, 3.5, ['harsh', 'debashish', 'manya'], ('rajiv', 'shabana'))

# %%
mixed_tuple[2].append([1,2,3,4])

# %%
mixed_tuple
# Out:
# (2, 3.5, ['harsh', 'debashish', 'manya', [1, 2, 3, 4]], ('rajiv', 'shabana'))

# %%
## membership ( in operator)
print(my_students)

"manya" in   my_students , "rajiv" in my_students
# Out:
# ['harsh', 'anubhav', 'manya', 'siddhi']
# (True, False)

# %% [markdown]
# ## tuple unpacking

# %%
## tuple upacking
num1, num2 = my_tuple

print(num1)
print(num2)
# Out:
# 20
# 30

# %%
student1, student2, student3 = ("siddhi", "shabana")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 student1, student2, student3 = ("siddhi", "shabana")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
student1, student2 = ("siddhi", "shabana", "rajiv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 student1, student2 = ("siddhi", "shabana", "rajiv")
#
# ValueError: too many values to unpack (expected 2)

# %%
student1
# Out:
# ('siddhi', 'shabana')

# %% [markdown]
# ## named tuples

# %% [markdown]
# ## using some basic funtions on list and tuples
#     - min
#     - max
#     - sum
#     - sorted

# %%
marks = (10, 20, 30, 40, 50)

## get the minimum in a list or tuple

min(marks), min(list(marks))
# Out:
# (10, 10)

# %%
max(marks)
# Out:
# 50

# %%
sum(marks)
# Out:
# 150

# %%
my_numbers = (3, 1, 9, 5, 2)

sorted(my_numbers)
# Out:
# [1, 2, 3, 5, 9]

# %%
my_numbers_list = list(my_numbers)
my_numbers_list.sort()  # inplace operation --> the my_numbers list is getting modified

# %%
my_numbers_list = list(my_numbers)
print(my_numbers_list)
sorted(my_numbers_list)  # not a inplace operation --> returns view of the object / creates a copy of the list
print(my_numbers_list)
# Out:
# [3, 1, 9, 5, 2]
# [3, 1, 9, 5, 2]

# %%
my_numbers_list = list(my_numbers)
print(my_numbers_list)
my_numbers_list.sort() # in place operation
print(my_numbers_list)
# Out:
# [3, 1, 9, 5, 2]
# [1, 2, 3, 5, 9]

# %%
my_numbers_list = list(my_numbers)
my_numbers_list.sort()
my_numbers_list
# Out:
# [1, 2, 3, 5, 9]

# %% [markdown]
# ## Why we need tuples?
#     - when we want data that should not be changed  (  eg. coordinates, )
#     - when a function is returning multiple
#     - performance and storage is better
#     - tuples can be used to represent a dictionary

# %%
import sys

my_tuple = ('harsh', 'anubhav', 'manya', 'siddhi')

sys.getsizeof(my_tuple)
# Out:
# 72

# %%
my_list = ['harsh', 'anubhav', 'manya', 'siddhi']
sys.getsizeof(my_list)
# Out:
# 88

# %%
# convert a list of tuples to a dictionary

data = [("siddhi", [30, 40, 50]) , ("rajiv", [70, 90])]

my_data_dict = dict(data)
my_data_dict
# Out:
# {'siddhi': [30, 40, 50], 'rajiv': [70, 90]}

# %%
data = [("siddhi", 30 , [30, 40, 50]) , ("rajiv", [70, 90])]
my_data_dict = dict(data)
my_data_dict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 data = [("siddhi", 30 , [30, 40, 50]) , ("rajiv", [70, 90])]
# ----> 2 my_data_dict = dict(data)
#       3 my_data_dict
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
new_data = {

    
}
my_data_dict.items()
# Out:
# {'siddhi': [30, 40, 50], 'rajiv': [70, 90]}
# dict_items([('siddhi', [30, 40, 50]), ('rajiv', [70, 90])])

# %%
marks = {

    "Siddhi" : {"English": 40, 
                "Hindi":30, 
                "Math": {"theory" : 80 , "practical":50}}, 
    
    "Shabana" : {"Science":45, "English" : 70}, 
    
    "Debashish" : {"English": 30,
                    "Hindi": 60,
                   "Math": {"theory":40, "practical":90}, 
                   "Science" : 10, 
                    "Art": 70}
}

list(marks.items())
# Out:
# [('Siddhi',
#   {'English': 40, 'Hindi': 30, 'Math': {'theory': 80, 'practical': 50}}),
#  ('Shabana', {'Science': 45, 'English': 70}),
#  ('Debashish',
#   {'English': 30,
#    'Hindi': 60,
#    'Math': {'theory': 40, 'practical': 90},
#    'Science': 10,
#    'Art': 70})]

# %%
(list(marks.items()))
# Out:
# [('Siddhi',
#   {'English': 40, 'Hindi': 30, 'Math': {'theory': 80, 'practical': 50}}),
#  ('Shabana', {'Science': 45, 'English': 70}),
#  ('Debashish',
#   {'English': 30,
#    'Hindi': 60,
#    'Math': {'theory': 40, 'practical': 90},
#    'Science': 10,
#    'Art': 70})]

# %% [markdown]
# # Sets
#
#     - unordered collection of unique items  ( there is no sequence or order)
#     - we will not access any element using any index
#     - we will check membership and do operations like union, intersection etc

# %%
empty_set = {}  # not an empty set. Empty dictionary

type(empty_set)
# Out:
# dict

# %%
empty_set = set()  # correct way to make empty set

type(empty_set)
# Out:
# set

# %%
my_set = {2, 5, 8, 3, c1}
my_set
# Out:
# {1, 2, 3, 5, 8}

# %%
type(my_set)
# Out:
# set

# %%
#we can add different datatypes in a set but mutable items


mixed_set = {20, 4.5}
mixed_set
# Out:
# {4.5, 20}

# %%
mixed_set = {20, 4.5, (1, 2)}
mixed_set
# Out:
# {(1, 2), 20, 4.5}

# %%
mixed_set = {20, 4.5, (1, 2), [3, 4, 5]}
mixed_set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 mixed_set = {20, 4.5, (1, 2), [3, 4, 5]}
#       2 mixed_set
#
# TypeError: unhashable type: 'list'

# %%
set(my_list)
# Out:
# {'anubhav', 'harsh', 'manya', 'siddhi'}

# %%
set(['harsh', 'anubhav', 'manya', 'siddhi', "anubhav"])
# Out:
# {'anubhav', 'harsh', 'manya', 'siddhi'}

# %%
## what are the things we can do in a set

print(dir(set()))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %% [markdown]
# ## Common operations on a set
#
#     'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update'

# %%
my_set = set(['harsh', 'anubhav', 'manya', 'siddhi', "anubhav", "rajiv", "shabana"])
my_set
# Out:
# {'anubhav', 'harsh', 'manya', 'rajiv', 'shabana', 'siddhi'}

# %%
len(my_set)
# Out:
# 7

# %%
## membership check

"ram" in my_set
# Out:
# True

# %%
my_set.add("ram")
my_set
# Out:
# {'anubhav', 'harsh', 'manya', 'rajiv', 'ram', 'shabana', 'siddhi'}

# %%
batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}

print(batsman.difference(bowlers))
print(bowlers.difference(batsman))
# Out:
# {'dhoni', 'rohit', 'kohli'}
# {'arshdeep', 'bumrah'}

# %%
bowlers - batsman
# Out:
# {'arshdeep', 'bumrah'}

# %%
batsman - bowlers
# Out:
# {'dhoni', 'kohli', 'rohit'}

# %%
batsman.intersection(bowlers)
# Out:
# {'pandya', 'yuvraj'}

# %%
batsman.union(bowlers)
# Out:
# {'arshdeep', 'bumrah', 'dhoni', 'kohli', 'pandya', 'rohit', 'yuvraj'}

# %%
batsman.difference(bowlers)
# Out:
# {'dhoni', 'kohli', 'rohit'}

# %%
batsman.difference_update(bowlers)

# %%
batsman
# Out:
# {'dhoni', 'kohli', 'rohit'}

# %%
batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}

print("batsman: "  ,  batsman)
print("Intersection:  " , batsman.intersection(bowlers))
batsman.intersection_update(bowlers)
print("After intersection update: " , batsman)
# Out:
# batsman:  {'dhoni', 'pandya', 'yuvraj', 'rohit', 'kohli'}
# Intersection:   {'pandya', 'yuvraj'}
# After intersection update:  {'pandya', 'yuvraj'}

# %%
# 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove'

batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}

footballers  = {"messi","ronaldo","kaka"}

# alternate way of writing the method
set.isdisjoint(batsman, bowlers)

print(batsman.isdisjoint(bowlers))

print(batsman.isdisjoint(footballers))
# Out:
# False
# True

# %%
batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}

allrounders = batsman.intersection(bowlers)


footballers  = {"messi","ronaldo","kaka"}


print(batsman.issubset(bowlers))

print(allrounders.issubset(batsman))

print(bowlers.issuperset(allrounders))
# Out:
# False
# True
# True

# %%
allrounders.add("gambhir")

print(batsman.issubset(bowlers))

print(allrounders.issubset(batsman))

print(bowlers.issuperset(allrounders))
# Out:
# False
# False
# False

# %%
batsman.remove("dhoni")

# %%
batsman
# Out:
# {'kohli', 'rohit', 'yuvraj'}

# %%
batsman = {'kohli', 'rohit', 'yuvraj'}
batsman.pop()
# Out:
# 'yuvraj'

# %%
# my_set = {3, 8, 1, 5, 9, 10}
print(my_set)
my_set.pop()
# Out:
# {10}
# 10

# %% [markdown]
# 'symmetric_difference', 'symmetric_difference_update', 'union', 'update'

# %%
batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}


print(set.symmetric_difference(batsman, bowlers))

set.symmetric_difference_update(batsman, bowlers)
batsman.symmetric_difference_update(bowlers)


print(batsman)
# Out:
# {'bumrah', 'dhoni', 'rohit', 'arshdeep', 'kohli'}
# {'pandya', 'dhoni', 'yuvraj', 'rohit', 'kohli'}

# %%
batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}

print(bowlers)
bowlers.symmetric_difference_update(batsman)

bowlers
# Out:
# {'arshdeep', 'pandya', 'yuvraj', 'bumrah'}
# {'arshdeep', 'bumrah', 'dhoni', 'kohli', 'rohit'}

# %%
batsman = {'kohli', 'dhoni', 'rohit', "pandya", "yuvraj"}
bowlers = {"bumrah", "arshdeep", "pandya", "yuvraj"}
batsman.update(bowlers)

# %%
batsman.union(bowlers)
# Out:
# {'arshdeep', 'bumrah', 'dhoni', 'kohli', 'pandya', 'rohit', 'yuvraj'}

# %%
batsman
# Out:
# {'arshdeep', 'bumrah', 'dhoni', 'kohli', 'pandya', 'rohit', 'yuvraj'}
